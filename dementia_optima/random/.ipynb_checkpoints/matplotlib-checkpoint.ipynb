# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(2)
x = np.arange(10.0)
y = np.arange(0,1,0.1)

plt.plot(x,y)

y = np.arange(1,2,0.1)

plt.plot(x,y)

# %%
plt.figure(figsize=(12, 12))
plt.subplot(231)
plt.subplot(232)
plt.subplot(233)
plt.subplot(223)
